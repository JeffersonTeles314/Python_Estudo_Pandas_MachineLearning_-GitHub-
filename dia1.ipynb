# %% [markdown]
# # Primeira Aula Sobre Análise de Dados com Python/Pandas

# %% [markdown]
# #### Importando

# %%
import pandas as pd

# %% [markdown]
# ##### Entendendo o DataFrame
# Nós Criamos DataFrames Passado os Valores de Cada Coluna Individualmente.

# %%
pd.DataFrame(
    {"Nome":['Cleuton','Flaubert'],
    "Nota":[9.8,9.5],
    "Media":[10,9]}
    )
# Out:
#        Nome  Nota  Media
# 0   Cleuton   9.8     10
# 1  Flaubert   9.5      9

# %%
pesquisa_sats = pd.DataFrame(
    {"Jefferson":['Gostei!','Não Gostei'],"Gabrielly":['Horrível!','Mais ou Menos!']}
    )

# %%
print(pesquisa_sats.head())
# Out:
#     Jefferson       Gabrielly
# 0     Gostei!       Horrível!
# 1  Não Gostei  Mais ou Menos!

# %%
pesquisa_sats.shape
# Out:
# (2, 2)

# %% [markdown]
# A intercessão de um lingha com culona é chamada de entrada

# %% [markdown]
# ##### Criação de Uma Série

# %%
pd.Series([0,1,2])
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int64

# %% [markdown]
# Carregando o Arquivo CSV

# %%
wine_reviews = pd.read_csv("C:/Users/Jefferson Teles/Desktop/01 - Finway/Soft/Python_Estudo_Pandas_MachineLearning_-GitHub-/winemag-data_first150k.csv")

# %%
print(wine_reviews.shape)
print(wine_reviews.head)
# Out:
# (150930, 11)
# <bound method NDFrame.head of         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# ...

# %%
#O Index col remove a coluna com os índicies do DataFrame
wine_reviews = pd.read_csv("C:/Users/Jefferson Teles/Desktop/01 - Finway/Soft/Python_Estudo_Pandas_MachineLearning_-GitHub-/winemag-data-130k-v2.csv", index_col=0)

# %%
print(wine_reviews.head)
# Out:
# <bound method NDFrame.head of          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# ...

# %%
wine_reviews.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews.price
# Out:
# 0          NaN
# 1         15.0
# 2         14.0
# 3         13.0
# 4         65.0
#           ...
# 129966    28.0
# 129967    75.0
# 129968    30.0
# 129969    32.0
# 129970    21.0
# Name: price, Length: 129971, dtype: float64

# %%
wine_reviews['country'][0]
# Out:
# 'Italy'

# %% [markdown]
# ### Iloc Trabalho com Indicies

# %%
# Retorna a Linha 0
wine_reviews.iloc[0]
# Out:
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# variety                                                        White Blend
# ...

# %%
#retorna a coluna 0
wine_reviews.iloc[:,0]
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews.iloc[1:3,0]
#selciona de 1 a 3 na coluna 0
# Out:
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
#Podemos usar linhas aninhadas para selecionar múltiplas listas
wine_reviews.iloc[[1,4,100],0]
# Out:
# 1      Portugal
# 4            US
# 100          US
# Name: country, dtype: object

# %%
#Seleciona as ultimas linhas, com valores negativos

wine_reviews.iloc[-5:]
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %%
wine_reviews.iloc[:,[0,3,4]]
# Out:
#          country  points  price
# 0          Italy      87    NaN
# 1       Portugal      87   15.0
# 2             US      87   14.0
# 3             US      87   13.0
# 4             US      87   65.0
# ...          ...     ...    ...
# 129966   Germany      90   28.0
# 129967        US      90   75.0
# 129968    France      90   30.0
# 129969    France      90   32.0
# 129970    France      90   21.0
#
# [129971 rows x 3 columns]

# %% [markdown]
# ### Loc Trabalha COn Rótulos

# %%
wine_reviews.loc[0,"country"]
# Out:
# 'Italy'

# %%
wine_reviews.loc[:,["points","price"]]
# Out:
#         points  price
# 0           87    NaN
# 1           87   15.0
# 2           87   14.0
# 3           87   13.0
# 4           87   65.0
# ...        ...    ...
# 129966      90   28.0
# 129967      90   75.0
# 129968      90   30.0
# 129969      90   32.0
# 129970      90   21.0
#
# [129971 rows x 2 columns]

# %%
wine_reviews.set_index('title')
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)             US
# St. Julian 2013 Reserve Late Harvest Riesling (...        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...        US
# ...                                                      ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...   Germany
# Citation 2004 Pinot Noir (Oregon)                         US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)    France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# ...

# %%
wine_reviews.country == "US"
# Out:
# 0         False
# 1         False
# 2          True
# 3          True
# 4          True
#           ...
# 129966    False
# 129967     True
# 129968    False
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
wine_reviews.loc[wine_reviews.country == "US"]
# Out:
#        country                                        description  \
# 2           US  Tart and snappy, the flavors of lime flesh and...
# 3           US  Pineapple rind, lemon pith and orange blossom ...
# 4           US  Much like the regular bottling from 2012, this...
# 10          US  Soft, supple plum envelopes an oaky structure ...
# 12          US  Slightly reduced, this wine offers a chalky, t...
# ...        ...                                                ...
# 129945      US  Hailing from one of the more popular vineyards...
# 129949      US  There's no bones about the use of oak in this ...
# 129950      US  This opens with herbaceous dollops of thyme an...
# 129952      US  This Zinfandel from the eastern section of Nap...
# 129967      US  Citation is given as much as a decade of bottl...
#
#                                designation  points  price    province  \
# 2                                      NaN      87   14.0      Oregon
# ...

# %%
wine_reviews.loc[(wine_reviews.country == "Italy") & (wine_reviews.region_1 == "Etna")]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 445      Italy  Vibrant and savory, this has aromas of red ber...
# 844      Italy  Aromas of citrus, white stone fruit and a vege...
# 861      Italy  Pressed wild flower, hay, fennel and ripe berr...
# ...        ...                                                ...
# 128690   Italy  Here's a surprise from Mt. Etna that blew us a...
# 128691   Italy  Don Peppino's vineyard lies on the lower slope...
# 128985   Italy  A blend based on Nerello Mascalese, with a tin...
# 129721   Italy  Made with 60% Carricante and 40% Catarratto, t...
# 129735   Italy  Dark-skinned berry, Mediterranean herb and for...
#
#                                   designation  points  price  \
# 0                                Vulkà Bianco      87    NaN
# ...

# %%
wine_reviews.loc[(wine_reviews.country == "Italy") & (wine_reviews.region_1 == "Etna") & (wine_reviews.points > 90)]
# Out:
#        country                                        description  \
# 4154     Italy  Made entirely with old Nerello Mascalese vines...
# 4523     Italy  Fragrant and loaded with finesse, this opens w...
# 4524     Italy  This gorgeous wine opens with aromas of smoke,...
# 5208     Italy  This elegant, structured red opens with a potp...
# 9456     Italy  Aromas of leather, flint, toast, menthol and e...
# ...        ...                                                ...
# 122725   Italy  Aromas of woodland berry, baking spice, orange...
# 128686   Italy  Serra della Contessa (named after Benanti's mo...
# 128690   Italy  Here's a surprise from Mt. Etna that blew us a...
# 128691   Italy  Don Peppino's vineyard lies on the lower slope...
# 128985   Italy  A blend based on Nerello Mascalese, with a tin...
#
#                                   designation  points  price  \
# 4154    Vigna Barbagalli Pre-Phylloxera Rosso      92  100.0
# ...

# %%
wine_reviews.loc[(wine_reviews.country == "Italy") | (wine_reviews.points > 90)]
# Operador ou
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 22       Italy  Delicate aromas recall white flower and citrus...
# 24       Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...        ...                                                ...
# 129940      US  This is the winery's bells and whistles Chardo...
# 129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
wine_reviews.loc[(wine_reviews.country.isin(["France","Germany"])) & (wine_reviews.points > 90)]
# Out:
#         country                                        description  \
# 119      France  Medium-gold in color. Complex and inviting nos...
# 126      France  Mid-gold color. Pronounced and enticing aromas...
# 127      France  Attractive mid-gold color with intense aromas ...
# 128      France  Compelling minerality on the nose, Refined and...
# 131      France  Attractive mid-gold color. Compelling layers o...
# ...         ...                                                ...
# 129918  Germany  Despite plenty of honeyed sweetness, this wine...
# 129923  Germany  Thick, oily and sweet, this wine is clearly no...
# 129924  Germany  Imagine honeyed orange sections—that's what th...
# 129931   France  A powerful, chunky wine, packed with solid tan...
# 129936   France  A blend from several premier cru vineyards in ...
#
#                                               designation  points  price  \
# 119            Schoenenbourg Grand Cru Vendanges Tardives      92   80.0
# ...

# %% [markdown]
# ### Funções de Resumo e Mapas

# %%
wine_reviews.points.describe()
# Out:
# count    129971.000000
# mean         88.447138
# std           3.039730
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %%
wine_reviews.country.describe()
# Out:
# count     129908
# unique        43
# top           US
# freq       54504
# Name: country, dtype: object

# %%
wine_reviews.country.unique()
#lista todos os valores (induviduais) Repetindo ou não da tabela
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %%
wine_reviews.country.value_counts()
# Out:
# country
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %%
wine_reviews.price.mean()
# Out:
# 35.363389129985535

# %%
wine_reviews.price.max()
# Out:
# 3300.0

# %%
wine_reviews.price.min()
# Out:
# 4.0

# %%
wine_reviews.price.std()
# Out:
# 41.02221766808723

# %%
wine_reviews.price.median()
# Out:
# 25.0

# %%
wine_reviews.groupby("points").points.count()
# Contamos o u=numero de vinhos de uma quantidade de pontos específico
# te permite realisar ações em faxas de valores específicas.
# pd.set_option('display.max_rows', None)
# Out:
# points
# 80       397
# 81       692
# 82      1836
# 83      3025
# 84      6480
# 85      9530
# 86     12600
# 87     16933
# 88     17207
# 89     12226
# 90     15410
# 91     11359
# 92      9613
# 93      6489
# 94      3758
# 95      1535
# 96       523
# 97       229
# 98        77
# 99        33
# 100       19
# Name: points, dtype: int64

# %%
pd.set_option('display.max_rows', None)

# %%
wine_reviews.price.dtype
# Te Fala o tipo de Dado da Coluna
# Out:
# dtype('float64')

# %%
wine_reviews.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
wine_reviews[pd.isnull(wine_reviews.country)]
#acha as linhas com valores nulos
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243       NaN  Violet-red in color, this semisweet wine has a...
# 9509       NaN  This mouthwatering blend starts with a nose of...
# 9750       NaN  This orange-style wine has a cloudy yellow-gol...
# ...        ...                                                ...
# 124176     NaN  This Swiss red blend is composed of four varie...
# 129407     NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408     NaN  El Capricho is one of Uruguay's more consisten...
# 129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900     NaN  This wine offers a delightful bouquet of black...
#
#                            designation  points  price province region_1  \
# 913                     Asureti Valley      87   30.0      NaN      NaN
# ...

# %%
wine_reviews[pd.isnull(wine_reviews.country)]

# %%
wine_reviews.country.fillna("Barack Obama")
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews.groupby("country").count()
# Out:
#                         description  designation  points  price  province  \
# country
# Argentina                      3800         2902    3800   3756      3800
# Armenia                           2            2       2      2         2
# Australia                      2329         1640    2329   2294      2329
# Austria                        3345         2825    3345   2799      3345
# Bosnia and Herzegovina            2            1       2      2         2
# Brazil                           52           51      52     47        52
# Bulgaria                        141           93     141    141       141
# Canada                          257          179     257    254       257
# Chile                          4472         3879    4472   4416      4472
# China                             1            1       1      1         1
# Croatia                          73           48      73     71        73
# ...

# %%
wine_reviews.taster_name.replace("Roger Voss", "Barack Obama")
# Out:
# 0              Kerin O’Keefe
# 1               Barack Obama
# 2               Paul Gregutt
# 3         Alexander Peartree
# 4               Paul Gregutt
#                  ...
# 129966    Anna Lee C. Iijima
# 129967          Paul Gregutt
# 129968          Barack Obama
# 129969          Barack Obama
# 129970          Barack Obama
# Name: taster_name, Length: 129971, dtype: object

# %%
wine_reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
wine_reviews.rename(columns={'points':'pontos'})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  pontos  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...
